# %% [markdown]
# <a href="https://colab.research.google.com/github/AroteRoshan/AI-ml-Data-analytics/blob/main/Roshan3yr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Read the Detasets

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/student.csv')

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.drop(5)
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.drop([5,7,8])
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 6     7     amar    BE  65.34   19
# 9    10    anmol    BE  78.66   21

# %%
df.drop('class',axis=1)
# Out:
#    roll     name  marks  age
# 0     1     anil  56.77   22
# 1     2     amit  59.77   21
# 2     3   aniket  76.88   19
# 3     4  ajinkya  69.66   20
# 4     5     asha  63.28   20
# 5     6   ayesha  49.55   20
# 6     7     amar  65.34   19
# 7     8    amita  68.33   23
# 8     9     amol  56.75   20
# 9    10    anmol  78.66   21

# %%
df.drop('class',axis=1)
# Out:
#    roll     name  marks  age
# 0     1     anil  56.77   22
# 1     2     amit  59.77   21
# 2     3   aniket  76.88   19
# 3     4  ajinkya  69.66   20
# 4     5     asha  63.28   20
# 5     6   ayesha  49.55   20
# 6     7     amar  65.34   19
# 7     8    amita  68.33   23
# 8     9     amol  56.75   20
# 9    10    anmol  78.66   21

# %% [markdown]
# #### Data import method

# %%
cols = ['A','B','C','D','E']
df1=pd. read_csv('/content/student.csv',names=cols)
df1
# Out:
#        A        B      C      D    E
# 0   roll     name  class  marks  age
# 1      1     anil     TE  56.77   22
# 2      2     amit     TE  59.77   21
# 3      3   aniket     BE  76.88   19
# 4      4  ajinkya     TE  69.66   20
# 5      5     asha     TE  63.28   20
# 6      6   ayesha     BE  49.55   20
# 7      7     amar     BE  65.34   19
# 8      8    amita     BE  68.33   23
# 9      9     amol     TE  56.75   20
# 10    10    anmol     BE  78.66   21

# %%
x=['M','M','M','M','F','F','M','F','M','M']
df [column]=x
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-a488b71b88a6> in <cell line: 2>()
#       1 x=['M','M','M','M','F','F','M','F','M','M']
# ----> 2 df [column]=x
#       3 df
#
# NameError: name 'column' is not defined

# %%
df['marks']=df['marks']+0.5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-2479e70e87d8> in <cell line: 1>()
# ----> 1 df['marks']=df['marks']+0.5
#
# NameError: name 'df' is not defined

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-00cf07b74dcd> in <cell line: 1>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# %%
df =pd.read_csv('student.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-5dedba05b9b5> in <cell line: 1>()
# ----> 1 df =pd.read_csv('student.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
import pandas as pd

# %%
 df=pd.read_csv('student.csv')

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
ndf=pd.DataFrame({
    'roll':range(1,11),
    'gender':['M','M','M','M','F','F','M','F','M','M'],
    'cgpa':df['marks']/10+0.37
})

# %%
ndf
# Out:
#    roll gender   cgpa
# 0     1      M  6.047
# 1     2      M  6.347
# 2     3      M  8.058
# 3     4      M  7.336
# 4     5      F  6.698
# 5     6      F  5.325
# 6     7      M  6.904
# 7     8      F  7.203
# 8     9      M  6.045
# 9    10      M  8.236

# %%
df=pd.read_csv('student.csv')

# %%
df.columns
# Out:
# Index(['roll', 'name', 'class', 'marks', 'age'], dtype='object')

# %%
ndf.columns
# Out:
# Index(['roll', 'gender', 'cgpa'], dtype='object')

# %%
df.merge(ndf,on='roll')
# Out:
#    roll     name class  marks  age gender   cgpa
# 0     1     anil    TE  56.77   22      M  6.047
# 1     2     amit    TE  59.77   21      M  6.347
# 2     3   aniket    BE  76.88   19      M  8.058
# 3     4  ajinkya    TE  69.66   20      M  7.336
# 4     5     asha    TE  63.28   20      F  6.698
# 5     6   ayesha    BE  49.55   20      F  5.325
# 6     7     amar    BE  65.34   19      M  6.904
# 7     8    amita    BE  68.33   23      F  7.203
# 8     9     amol    TE  56.75   20      M  6.045
# 9    10    anmol    BE  78.66   21      M  8.236

# %%
df5=pd.read_csv('/content/student5.csv')

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
pd.concat([df,df5],ignore_index=True)
# Out:
#     roll     name class  marks  age
# 0      1     anil    TE  56.77   22
# 1      2     amit    TE  59.77   21
# 2      3   aniket    BE  76.88   19
# 3      4  ajinkya    TE  69.66   20
# 4      5     asha    TE  63.28   20
# 5      6   ayesha    BE  49.55   20
# 6      7     amar    BE  65.34   19
# 7      8    amita    BE  68.33   23
# 8      9     amol    TE  56.75   20
# 9     10    anmol    BE  78.66   21
# 10     1   surbhi    TE  67.44   23
# 11     2    sujay    TE  74.12   22
# 12     3  subhash    BE  82.44   21
# 13     4   sachin    TE  59.33   21
# 14     5  shalini    TE  63.45   20

# %% [markdown]
# #### method or function

# %%
df['marks'].max()
# Out:
# 78.66

# %%
df['marks'].min()
# Out:
# 49.55

# %%
df['marks'].sum()
# Out:
# 644.9899999999999

# %%
df['marks'].median()
# Out:
# 64.31

# %%
df['marks'].std()
# Out:
# 9.207178901994535

# %%
df['class'].mode()
# Out:
# 0    BE
# 1    TE
# Name: class, dtype: object

# %%
df['class'].value_counts()
# Out:
# TE    5
# BE    5
# Name: class, dtype: int64

# %%
df['age'].value_counts()
# Out:
# 20    4
# 21    2
# 19    2
# 22    1
# 23    1
# Name: age, dtype: int64

# %%
df.sum()
# Out:
# roll                                                    55
# name     anilamitaniketajinkyaashaayeshaamaramitaamolanmol
# class                                 TETEBETETEBEBEBETEBE
# marks                                               644.99
# age                                                    205
# dtype: object

# %%
df.min()
# Out:
# roll           1
# name     ajinkya
# class         BE
# marks      49.55
# age           19
# dtype: object

# %%
df.mean()
# Out:
# <ipython-input-40-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# roll      5.500
# marks    64.499
# age      20.500
# dtype: float64

# %%
df.describe()
# Out:
#            roll      marks        age
# count  10.00000  10.000000  10.000000
# mean    5.50000  64.499000  20.500000
# std     3.02765   9.207179   1.269296
# min     1.00000  49.550000  19.000000
# 25%     3.25000  57.520000  20.000000
# 50%     5.50000  64.310000  20.000000
# 75%     7.75000  69.327500  21.000000
# max    10.00000  78.660000  23.000000

# %% [markdown]
# #### string opereations

# %%
df['name'].str.upper()
# Out:
# 0       ANIL
# 1       AMIT
# 2     ANIKET
# 3    AJINKYA
# 4       ASHA
# 5     AYESHA
# 6       AMAR
# 7      AMITA
# 8       AMOL
# 9      ANMOL
# Name: name, dtype: object

# %%
df['name'].str.lower()
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5     ayesha
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df['name'].str.title()
# Out:
# 0       Anil
# 1       Amit
# 2     Aniket
# 3    Ajinkya
# 4       Asha
# 5     Ayesha
# 6       Amar
# 7      Amita
# 8       Amol
# 9      Anmol
# Name: name, dtype: object

# %%
df['name'].str.swapcase()
# Out:
# 0       ANIL
# 1       AMIT
# 2     ANIKET
# 3    AJINKYA
# 4       ASHA
# 5     AYESHA
# 6       AMAR
# 7      AMITA
# 8       AMOL
# 9      ANMOL
# Name: name, dtype: object

# %%
df['name'].str.replace('i','ee')
# Out:
# 0       aneel
# 1       ameet
# 2     aneeket
# 3    ajeenkya
# 4        asha
# 5      ayesha
# 6        amar
# 7      ameeta
# 8        amol
# 9       anmol
# Name: name, dtype: object

# %%
df['name'].str.count('a')
# Out:
# 0    1
# 1    1
# 2    1
# 3    2
# 4    2
# 5    2
# 6    2
# 7    2
# 8    1
# 9    1
# Name: name, dtype: int64

# %%
df['name'].str.startswith('an')
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9     True
# Name: name, dtype: bool

# %%
df['name'].str.endswith('l')
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8     True
# 9     True
# Name: name, dtype: bool

# %% [markdown]
# #### Grouping Opereations

# %%
gr=df.groupby('class')

# %%
gr.groups
# Out:
# {'BE': [2, 5, 6, 7, 9], 'TE': [0, 1, 3, 4, 8]}

# %%
gr.get_group('TE')
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 8     9     amol    TE  56.75   20

# %%
gr.get_group('BE')
# Out:
#    roll    name class  marks  age
# 2     3  aniket    BE  76.88   19
# 5     6  ayesha    BE  49.55   20
# 6     7    amar    BE  65.34   19
# 7     8   amita    BE  68.33   23
# 9    10   anmol    BE  78.66   21

# %%
gr.agg(min)
# Out:
#        roll     name  marks  age
# class
# BE        3     amar  49.55   19
# TE        1  ajinkya  56.75   20

# %% [markdown]
# #### Boolean Filterning

# %%
df['marks']>60
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# 5    False
# 6     True
# 7     True
# 8    False
# 9     True
# Name: marks, dtype: bool

# %%
mask=df['marks']>60

# %%
df[mask]
# Out:
#    roll     name class  marks  age
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 9    10    anmol    BE  78.66   21

# %%
df[df['marks']>60]
# Out:
#    roll     name class  marks  age
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 9    10    anmol    BE  78.66   21

# %%
df[df['name'].str.startswith('an')]
# Out:
#    roll    name class  marks  age
# 0     1    anil    TE  56.77   22
# 2     3  aniket    BE  76.88   19
# 9    10   anmol    BE  78.66   21

# %%
x=df[(df['marks']>60)&(df['class']=='BE')]

# %%
x
# Out:
#    roll    name class  marks  age
# 2     3  aniket    BE  76.88   19
# 6     7    amar    BE  65.34   19
# 7     8   amita    BE  68.33   23
# 9    10   anmol    BE  78.66   21

# %%
x=df[(df['marks']>60)&(df['class']=='TE')]

# %%
x
# Out:
#    roll     name class  marks  age
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20

# %% [markdown]
# #### Export The Data

# %%
x.to_csv('output.csv', index=False)

# %%
x.to_html('output.html',index=False)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
x = np.array([3,8,12,14,15,24,38,42,49,55])
y=np.array([11,2,45,66,54,23,78,98,44,21,])
z=np.array([76,45,78,54,2,33,12,43,90,56])
p=np.array([34,66,22,87,54,32,12,98,86,45,])

# %% [markdown]
# #### Scatter plot

# %%
plt.plot(x,y)

# %%
plt.plot(x,p)

# %%
plt.plot(y,z)

# %%
plt.title('my first plot')
plt.xlabel('first value')
plt.ylabel('second value')
plt.xlabel('first value')
plt.grid()
plt.xlim(0,70)
plt.ylim(0,100)
plt.yticks(range(0,100,10))
plt.plot(x,y)

# %%
plt.title('my first plot')
plt.xlabel('first value')
plt.ylabel('second value')
plt.grid()
plt.xlim(0,70)
plt.ylim(0,100)
plt.yticks(range(0,100,10))
plt.plot(x,y,color ='orange', marker='o')

# %%
df=pd.read_csv('student.csv')

# %%
plt.title('Roll vs Marks')
plt.xlabel('Roll Number')
plt.ylabel('Marks')
plt.grid()
plt.xlim(0,11)
plt.ylim(40,100)
plt.plot(df['roll'],df['marks'],color='blue',marker='o')

# %%
plt.title('my first plot')
plt.xlabel('first value')
plt.ylabel('second value')
plt.grid()
plt.xlim(0,70)
plt.ylim(0,100)
plt.yticks(range(0,100,10))
plt.plot(x,y,color='red',label='2023')
plt.plot(x,z,color='green',label='2024')
plt.legend()

# %%
plt.subplot(1,2,1)
plt.plot(x,y,color='r')
plt.subplot(1,2,2)
plt.plot(x,z,color='g')

# %% [markdown]
# #### scatter plot

# %%
plt.figure(figsize=(16,9))
plt.scatter(x,y)

# %% [markdown]
# #### Bar Plot

# %%
plt.figure(figsize=(16,9))
plt.xlabel('students Name')
plt.ylabel('Marks')
plt.bar(df['Name'],df['Marks'],color='maroon')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
studs=[56,78,47,168,123,41]
langs=['c','c++','java','python','r','php']

plt.pie(studs, labels=langs, autopct='%2.2f%%');

# %% [markdown]
# ####Histogram

# %%
x=[45,66,54,23,67,68,98,56,61,62,56,89,77]
plt.title('Histogram')
plt.xlabel('range')
plt.ylabel('count')
plt.grid()
plt.xticks(range(0,100,10))
plt.hist(x,bins=range(0,100,10));

# %%
plt.xlabel('values')
plt.ylabel('range')
plt.boxplot(x);

# %% [markdown]
# **Datasets**
