# %% [markdown]
# <a href="https://colab.research.google.com/github/AroteRoshan/AI-ml-Data-analytics/blob/main/Data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Datasets**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Read the data**

# %%
df=pd.read_csv("/content/student3.csv")

# %%
df
# Out:
#     roll     name class  marks    age
# 0      1     anil    TE   56.77  22.0
# 1      2     amit    TE   59.77  21.0
# 2      3   aniket    BE   76.88  19.0
# 3      4  ajinkya    TE   69.66  20.0
# 4      5     asha    TE   63.28   NaN
# 5      6   ayesha    BE     NaN  20.0
# 6      7     amar    BE   65.34  19.0
# 7      8    Amita    be   68.33  23.0
# 8      9     amol    TE   56.75  20.0
# 9      9     amol    TE   56.75  20.0
# 10    10    anmol    BE   78.66   NaN
# 11    11   surbhi    TE     NaN  23.0
# 12    12    Sujay    TE   74.12  22.0
# 13    13  subhash    be   88.45  21.0
# 14    14   sachin   NaN   59.33  21.0
# 15    15  shalini    TE   63.45  20.0

# %%
df.shape
# Out:
# (16, 5)

# %%
df['age'].mean()
# Out:
# 20.785714285714285

# %%
df['age'].max()
# Out:
# 23.0

# %%
df['marks '].head()
# Out:
# 0    56.77
# 1    59.77
# 2    76.88
# 3    69.66
# 4    63.28
# Name: marks , dtype: float64

# %%
df['marks '].tail()
# Out:
# 11      NaN
# 12    74.12
# 13    88.45
# 14    59.33
# 15    63.45
# Name: marks , dtype: float64

# %%
df['marks '].mean()
# Out:
# 66.96714285714286

# %%
df['marks '].min()
# Out:
# 56.75

# %%
df.columns
# Out:
# Index(['roll', 'name', 'class', 'marks ', 'age'], dtype='object')

# %%
df.columns.str.strip()
df.columns
# Out:
# Index(['roll', 'name', 'class', 'marks ', 'age'], dtype='object')

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
df['class'].value_counts()
# Out:
# TE    9
# BE    4
# be    2
# Name: class, dtype: int64

# %%
df['class']=df['class'].str.upper()

# %%
df['class'].value_counts()
# Out:
# TE    9
# BE    6
# Name: class, dtype: int64

# %%
df['name']=df['name'].str.title()
df
# Out:
#     roll     name class  marks    age
# 0      1     Anil    TE   56.77  22.0
# 1      2     Amit    TE   59.77  21.0
# 2      3   Aniket    BE   76.88  19.0
# 3      4  Ajinkya    TE   69.66  20.0
# 4      5     Asha    TE   63.28   NaN
# 5      6   Ayesha    BE     NaN  20.0
# 6      7     Amar    BE   65.34  19.0
# 7      8    Amita    be   68.33  23.0
# 8      9     Amol    TE   56.75  20.0
# 9      9     Amol    TE   56.75  20.0
# 10    10    Anmol    BE   78.66   NaN
# 11    11   Surbhi    TE     NaN  23.0
# 12    12    Sujay    TE   74.12  22.0
# 13    13  Subhash    be   88.45  21.0
# 14    14   Sachin   NaN   59.33  21.0
# 15    15  Shalini    TE   63.45  20.0

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# dtype: bool

# %%
df[df.duplicated()]
# Out:
#    roll  name class  marks    age
# 9     9  Amol    TE   56.75  20.0

# %%
df.drop_duplicates()
# Out:
#     roll     name class  marks    age
# 0      1     Anil    TE   56.77  22.0
# 1      2     Amit    TE   59.77  21.0
# 2      3   Aniket    BE   76.88  19.0
# 3      4  Ajinkya    TE   69.66  20.0
# 4      5     Asha    TE   63.28   NaN
# 5      6   Ayesha    BE     NaN  20.0
# 6      7     Amar    BE   65.34  19.0
# 7      8    Amita    be   68.33  23.0
# 8      9     Amol    TE   56.75  20.0
# 10    10    Anmol    BE   78.66   NaN
# 11    11   Surbhi    TE     NaN  23.0
# 12    12    Sujay    TE   74.12  22.0
# 13    13  Subhash    be   88.45  21.0
# 14    14   Sachin   NaN   59.33  21.0
# 15    15  Shalini    TE   63.45  20.0

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#     roll     name class  marks    age
# 0      1     Anil    TE   56.77  22.0
# 1      2     Amit    TE   59.77  21.0
# 2      3   Aniket    BE   76.88  19.0
# 3      4  Ajinkya    TE   69.66  20.0
# 4      5     Asha    TE   63.28   NaN
# 5      6   Ayesha    BE     NaN  20.0
# 6      7     Amar    BE   65.34  19.0
# 7      8    Amita    be   68.33  23.0
# 8      9     Amol    TE   56.75  20.0
# 10    10    Anmol    BE   78.66   NaN
# 11    11   Surbhi    TE     NaN  23.0
# 12    12    Sujay    TE   74.12  22.0
# 13    13  Subhash    be   88.45  21.0
# 14    14   Sachin   NaN   59.33  21.0
# 15    15  Shalini    TE   63.45  20.0

# %%
df.count()
# Out:
# roll      15
# name      15
# class     14
# marks     13
# age       13
# dtype: int64

# %%
df.isnull()
# Out:
#      roll   name  class  marks     age
# 0   False  False  False   False  False
# 1   False  False  False   False  False
# 2   False  False  False   False  False
# 3   False  False  False   False  False
# 4   False  False  False   False   True
# 5   False  False  False    True  False
# 6   False  False  False   False  False
# 7   False  False  False   False  False
# 8   False  False  False   False  False
# 10  False  False  False   False   True
# 11  False  False  False    True  False
# 12  False  False  False   False  False
# 13  False  False  False   False  False
# 14  False  False   True   False  False
# 15  False  False  False   False  False

# %%
True+False
# Out:
# 1

# %%
True+True
# Out:
# 2

# %%
df.isnull().sum()
# Out:
# roll      0
# name      0
# class     1
# marks     2
# age       2
# dtype: int64

# %%
#1
df.dropna()
# Out:
#     roll     name class  marks    age
# 0      1     Anil    TE   56.77  22.0
# 1      2     Amit    TE   59.77  21.0
# 2      3   Aniket    BE   76.88  19.0
# 3      4  Ajinkya    TE   69.66  20.0
# 6      7     Amar    BE   65.34  19.0
# 7      8    Amita    be   68.33  23.0
# 8      9     Amol    TE   56.75  20.0
# 12    12    Sujay    TE   74.12  22.0
# 13    13  Subhash    be   88.45  21.0
# 15    15  Shalini    TE   63.45  20.0

# %%
#2
df.columns=df.columns.str.strip()
df.columns
# Out:
# Index(['roll', 'name', 'class', 'marks', 'age'], dtype='object')

# %%
df['marks'].fillna(60)
# Out:
# 0     56.77
# 1     59.77
# 2     76.88
# 3     69.66
# 4     63.28
# 5     60.00
# 6     65.34
# 7     68.33
# 8     56.75
# 9     56.75
# 10    78.66
# 11    60.00
# 12    74.12
# 13    88.45
# 14    59.33
# 15    63.45
# Name: marks, dtype: float64

# %%
df['marks'].fillna(df['marks'].mean())
# Out:
# 0     56.770000
# 1     59.770000
# 2     76.880000
# 3     69.660000
# 4     63.280000
# 5     66.967143
# 6     65.340000
# 7     68.330000
# 8     56.750000
# 9     56.750000
# 10    78.660000
# 11    66.967143
# 12    74.120000
# 13    88.450000
# 14    59.330000
# 15    63.450000
# Name: marks, dtype: float64

# %%
df['age'].fillna(df['age'].median())
# Out:
# 0     22.0
# 1     21.0
# 2     19.0
# 3     20.0
# 4     20.5
# 5     20.0
# 6     19.0
# 7     23.0
# 8     20.0
# 9     20.0
# 10    20.5
# 11    23.0
# 12    22.0
# 13    21.0
# 14    21.0
# 15    20.0
# Name: age, dtype: float64

# %%
df['class'].mode()
# Out:
# 0    TE
# Name: class, dtype: object

# %%
df['class'].mode()[0]
# Out:
# 'TE'

# %%
df['class'].fillna(df['class'].mode()[0])
# Out:
# 0     TE
# 1     TE
# 2     BE
# 3     TE
# 4     TE
# 5     BE
# 6     BE
# 7     be
# 8     TE
# 9     TE
# 10    BE
# 11    TE
# 12    TE
# 13    be
# 14    TE
# 15    TE
# Name: class, dtype: object

# %%
df.fillna(method='pad')
# Out:
#     roll     name class  marks   age
# 0      1     anil    TE  56.77  22.0
# 1      2     amit    TE  59.77  21.0
# 2      3   aniket    BE  76.88  19.0
# 3      4  ajinkya    TE  69.66  20.0
# 4      5     asha    TE  63.28  20.0
# 5      6   ayesha    BE  63.28  20.0
# 6      7     amar    BE  65.34  19.0
# 7      8    Amita    BE  68.33  23.0
# 8      9     amol    TE  56.75  20.0
# 9      9     amol    TE  56.75  20.0
# 10    10    anmol    BE  78.66  20.0
# 11    11   surbhi    TE  78.66  23.0
# 12    12    Sujay    TE  74.12  22.0
# 13    13  subhash    BE  88.45  21.0
# 14    14   sachin    BE  59.33  21.0
# 15    15  shalini    TE  63.45  20.0

# %%
df.ffill()
# Out:
#     roll     name class  marks   age
# 0      1     anil    TE  56.77  22.0
# 1      2     amit    TE  59.77  21.0
# 2      3   aniket    BE  76.88  19.0
# 3      4  ajinkya    TE  69.66  20.0
# 4      5     asha    TE  63.28  20.0
# 5      6   ayesha    BE  63.28  20.0
# 6      7     amar    BE  65.34  19.0
# 7      8    Amita    BE  68.33  23.0
# 8      9     amol    TE  56.75  20.0
# 9      9     amol    TE  56.75  20.0
# 10    10    anmol    BE  78.66  20.0
# 11    11   surbhi    TE  78.66  23.0
# 12    12    Sujay    TE  74.12  22.0
# 13    13  subhash    BE  88.45  21.0
# 14    14   sachin    BE  59.33  21.0
# 15    15  shalini    TE  63.45  20.0

# %%
df.bfill()
# Out:
#     roll     name class  marks   age
# 0      1     anil    TE  56.77  22.0
# 1      2     amit    TE  59.77  21.0
# 2      3   aniket    BE  76.88  19.0
# 3      4  ajinkya    TE  69.66  20.0
# 4      5     asha    TE  63.28  20.0
# 5      6   ayesha    BE  65.34  20.0
# 6      7     amar    BE  65.34  19.0
# 7      8    Amita    BE  68.33  23.0
# 8      9     amol    TE  56.75  20.0
# 9      9     amol    TE  56.75  20.0
# 10    10    anmol    BE  78.66  23.0
# 11    11   surbhi    TE  74.12  23.0
# 12    12    Sujay    TE  74.12  22.0
# 13    13  subhash    BE  88.45  21.0
# 14    14   sachin    TE  59.33  21.0
# 15    15  shalini    TE  63.45  20.0
